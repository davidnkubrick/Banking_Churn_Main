# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data\dataset_with_AGE_and_INF.csv',index_col=0)

# %%
cols_to_drop = ['DATE','creation_date','customer_id','dob','total_cum_count_interactions'
                ,'no_of_monthly_deposits','no_of_monthly_withdrawals','monthly_interactions'
                ,'monthly_transactions','SENT','PSR','GDP/C','EXP/C','state','churn0.1','churn0.3','churn0.5','churn0.7','churn0.9']

df.drop(cols_to_drop,axis=1,inplace=True)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\DavidNeilan\AppData\Local\Temp\ipykernel_7992\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.drop([],axis=1,inplace=True)

# %%
# Out:
# Index(['UNEMP', 'start_balance', 'monthly_withdrawal', 'monthly_deposit',
#        'churn', 'total_cum_sum_withdrawal', 'total_cum_sum_deposit',
#        'end_of_month_balance', 'total_cum_count_transactions', 'max_account',
#        'net_diff', 'start_month_balance', '3month_rolling_sum',
#        '6month_rolling_sum', '12month_rolling_sum', '3month_rolling_max',
#        '6month_rolling_max', '12month_rolling_max', 'three_monthly_decay',
#        '6_monthly_decay', '12_monthly_decay', 'UNEMP_rolling', 'CHURN', 'age',
#        'INF'],
#       dtype='object')

# %%
df.drop(['6month_rolling_sum','monthly_deposit','6month_rolling_max',],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['UNEMP', 'start_balance', 'monthly_withdrawal',
#        'total_cum_sum_withdrawal', 'total_cum_sum_deposit',
#        'end_of_month_balance', 'total_cum_count_transactions', 'max_account',
#        'net_diff', 'start_month_balance', '3month_rolling_sum',
#        '12month_rolling_sum', '3month_rolling_max', '12month_rolling_max',
#        'three_monthly_decay', '6_monthly_decay', '12_monthly_decay',
#        'UNEMP_rolling', 'CHURN', 'age', 'INF'],
#       dtype='object')

# %%
df.to_csv('Modelling_DATA.csv')

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >
